# %%
import os, sys, glob
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from keras.models import load_model
model = load_model('../models/model_03.h5')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\aamico\AppData\Local\Continuum\anaconda3\envs\deep_mouse\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\aamico\AppData\Local\Continuum\anaconda3\envs\deep_mouse\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Users\aamico\AppData\Local\Continuum\anaconda3\envs\deep_mouse\lib\site-packages\keras\engine\saving.py:327: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
import h5py

with h5py.File(f'../data/data_xception.h5', 'r') as f:
    X_test, y_test = f['X_test'][()], f['y_test'][()]

# %%
y_cat = np.argmax(y_test, axis=1)

# %%
np.where(y_cat==4)
# Out:
# (array([ 14,  18,  31,  42,  45,  67,  87,  88, 108, 140, 142, 153, 154,
#         168, 172, 188, 190, 250, 270, 283, 305, 315, 336, 341, 345, 369,
#         372, 379, 384, 391, 412, 418, 424, 436, 446, 449, 453, 467, 489,
#         505, 511, 516, 519, 521], dtype=int64),)

# %%
plt.imshow(X_test[14])

# %%
y_pred = model.predict(X_test[y_cat==4,...])

# %%
plt.errorbar(range(5), y_pred.mean(0), y_pred.std(0), fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>
